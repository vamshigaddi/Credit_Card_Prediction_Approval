# %%
# !pip install auto-gptq
# !pip install --upgrade optimum
# !pip install --upgrade git+https://github.com/huggingface/transformers.git
# !pip install --upgrade accelerate
# !pip install bitsandbytes
# Out:
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 42.9 MB/s eta 0:00:00
# Collecting accelerate>=0.26.0 (from auto-gptq)
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 37.5 MB/s eta 0:00:00
# Collecting datasets (from auto-gptq)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 53.1 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.6-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.1.0+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.38.1)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 27.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.15.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->auto-gptq)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Collecting multiprocess (from datasets->auto-gptq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, dill, multiprocess, accelerate, datasets, peft, auto-gptq
# Successfully installed accelerate-0.27.2 auto-gptq-0.7.1 datasets-2.18.0 dill-0.3.8 gekko-1.0.6 multiprocess-0.70.16 peft-0.9.0 rouge-1.0.1
# Collecting optimum
#   Downloading optimum-1.17.1-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 3.3 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (4.38.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum) (2.1.0+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum) (1.16.0)
# Installing collected packages: humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.17.1
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-rvgcehif
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-rvgcehif
#   Resolved https://github.com/huggingface/transformers.git to commit 836921fdeb498820b71dcc7b70e990e828f4c6bc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.39.0.dev0) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.39.0.dev0) (2024.2.2)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.39.0.dev0-py3-none-any.whl size=8648192 sha256=1eb278881406442d2ca84d3087fee104d9e5dcd2fabbb6b44b44a78a8da5852b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9kc9pzy6/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.1
#     Uninstalling transformers-4.38.1:
#       Successfully uninstalled transformers-4.38.1
# Successfully installed transformers-4.39.0.dev0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->bitsandbytes) (1.25.2)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.42.0

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:512"

# %%
model_name =  "mistralai/Mistral-7B-v0.1"

# Fine-tuned model name
#new_model = "Llama-2-7b-chat-finetune"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False
device_map = {"": 0}

# %%
import os
import torch
#from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

# %%
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
import os

mk_dir = 'contents/model_path'
if not os.path.exists(mk_dir):
    os.makedirs(mk_dir)
save_folder = mk_dir  # Set save_folder to the created directory

# %%
save_folder = 'contents/model_path'
model.save_pretrained(save_folder)

# %%
torch.cuda.empty_cache()

# %%
from transformers import AutoModelForCausalLM

# Replace 'contents/model_path' with the path where the quantized model is saved
model_name = 'contents/model_path'

# Load the quantized model and set low_cpu_mem_usage to True
quantized_model = AutoModelForCausalLM.from_pretrained(model_name, low_cpu_mem_usage=True)

# %%
from accelerate import Accelerator
accelerator = Accelerator()
quantized_model = accelerator.prepare(quantized_model)

# %%
import torch

# Define and initialize the device variable
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import time
def run_inference(quantized_model, tokenizer, device, prompts):
    input_data = tokenizer(prompts, padding=True, truncation=True, return_tensors="pt").to(device)

    # Generate text responses
    start_time = time.time()
    with torch.no_grad():
        generated_outputs = quantized_model.generate(input_ids=input_data["input_ids"],
                                           attention_mask=input_data["attention_mask"],
                                           max_length=128,
                                           repetition_penalty=1.355,  # Adjust repetition penalty
                                           temperature=0.1,  # Adjust temperature
                                           num_return_sequences=1,  # Limit to 1 sequence per prompt
                                           do_sample=True
                                           )
    output_time = time.time() - start_time

    generated_texts = [tokenizer.decode(g, skip_special_tokens=True) for g in generated_outputs]

    # Measure GPU memory allocated
    gpu_memory_allocated = torch.cuda.max_memory_allocated() / (1024 ** 2)

    # Calculate token count for throughput calculation
    token_count = sum([input_data[k].nelement() for k in input_data.keys()])

    return {
        "outputs": generated_texts,
        "output_time": output_time,
        "throughput": token_count / output_time,
        "gpu_memory_allocated": gpu_memory_allocated
    }

# %%
# Define the list of prompts
prompts = [
    "What is the capital of Japan?",
    "Who wrote the novel 'To Kill a Mockingbird'?",
    "What is the boiling point of water?",
    "How do I make a chocolate cake?",
    "What are the symptoms of COVID-19?",
    "Can you explain the theory of relativity?",
    "Who won the Nobel Prize in Literature last year?",
    "What is the population of India?",
    "How do I change a flat tire?",
    "What is the square root of 144?",
    # Add additional prompts to ensure there are 32 questions
    "What is the capital of France?",
    "Who is the current President of the United States?",
    "What is the largest mammal on Earth?",
    "How do I bake a pizza?",
    "What are the types of clouds?",
    "Explain the process of photosynthesis.",
    "Who painted the Mona Lisa?",
    "What is the currency of Japan?",
    "How do I tie a necktie?",
    "What are the ingredients of a cheeseburger?",
    "Who discovered gravity?",
    "What is the speed of light?",
    "How do I cook rice?",
    "What is the tallest mountain in the world?",
    "Who wrote the play 'Romeo and Juliet'?",
    "What are the primary colors?",
    "What is the capital of Australia?",
    "How do I send an email?",
    "What is the distance between the Earth and the Moon?",
    "Who invented the telephone?",
    "What is the main component of air?"
]

# Run inference for the given prompts
inference_results = run_inference(quantized_model, tokenizer, device, prompts)



print("Outputs:")
for prompt, output in zip(prompts, inference_results["outputs"]):
    print(f"Prompt: {prompt}")

     # Filter out the repeated question
    filtered_output = output.replace(prompt, "", 1).strip()

    print(f"Generated Text: {filtered_output}")
    #print(f"Generated Text: {output}")


# Measure and print additional metrics
print(f"Output time: {inference_results['output_time']:.2f} seconds")
print(f"Throughput: {inference_results['throughput']:.2f} tokens/second")
print(f"GPU Memory Allocated: {inference_results['gpu_memory_allocated']:.2f} MB")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Outputs:
# Prompt: What is the capital of Japan?
# Generated Text: т
#
# Tokyo. Tokyo, officially known as Tо̄kyō (東京), or Eastern Capital in English, and formerly Nihonbashi-to (日本橋都) during Edo period, is one of 47 prefectures of Japan. It was established on May 15th, 1869 by merging three former provinces: Musashino Province, Shimotsuke Province, Koshinetsu Province. The city has a population of over 30 million people making it
# Prompt: Who wrote the novel 'To Kill a Mockingbird'?
# Generated Text: Harper Lee. The author of To Kill A Mocking Bird is Harper Lee, who was born in 1926 and died on February 19th, 2016 at age ninety-four. She grew up with her sister Alice (who also became an acclaimed writer) near Monroeville Alabama where she attended Huntingdon College before moving to New York City after World War II ended; there are many stories about how this small town inspired some aspects from both books but it seems clear that most people agree they
# Prompt: What is the boiling point of water?
# Generated Text: м
#
# The temperature at which a liquid changes to gas. The boiling points for different liquids are determined by their molecular structure and intermolecular forces, as well as atmospheric pressure (which affects how much energy it takes to overcome these interactions). For example: H2O has an extremely high melting/boiling point because its molecules have strong hydrogen bonds that must be broken before they can escape into vapor form; this requires more heat than other substances with weaker bonding between atoms or ions such as NaCl
# Prompt: How do I make a chocolate cake?
# Generated Text: ́
#
# This is the question that every baker has asked themselves at some point. The answer, of course, depends on what kind of chocolate you want to use and how much time you have available for baking! If your goal is an easy recipe with minimal ingredients then this blog post will help guide through making delicious homemade cakes from scratch using only three simple steps: mixing together dry goods (flour/sugar), adding wet ones like eggs or milk before finally pouring into pans where they’ll cook until done perfectly golden brown inside while still
# Prompt: What are the symptoms of COVID-19?
# Generated Text: м
#
# The most common signs and symptoms include: fever, coughing or sneezing; difficulty breathing (shortness of breath); fatigue. Other less frequent but more serious complications can be pneumonia in both lungs, kidney failure, heart problems such as myocarditis/pericardial effusion with arrhythmias etc., neurological disorders like encephalopathy which may lead to seizures if untreated properly by doctors who know how best treat these conditions based on their experience working closely together over many years now
# Prompt: Can you explain the theory of relativity?
# Generated Text: й
#
# The answer is simple: No. The question, however, has a more complex history than that short response might suggest. In 1905 Albert Einstein published four papers in Annalen der Physik (Annals of physics), one on Brownian motion and three on special relativity. These were followed by two further articles on general relativity in 1916. It was not until 20 years later that he wrote his first book-length account of these theories, RelativitГ¤tsprinzip und die
# Prompt: Who won the Nobel Prize in Literature last year?
# Generated Text: до 2018-09-30
#
# Who Won The Noble Peace Price In 2017.The nobel peace prize for 2016 was awarded to john o'sullivan, a journalist and editor of new york magazine who has been credited with coining the term "the arab spring" during his time as an analyst at cnn.. What Is A Good Book To Read About World War Ii?.World war ii (often abbreviated wwii or wwi
# Prompt: What is the population of India?
# Generated Text: ́
#
# India has a total area of 3,287,590 km² and its current estimated population as per census in July 1st , 2016 was around 1.2 billion people (as on March 4th, 2011). The country’s capital city New Delhi also happens to be one among many other major cities like Mumbai or Bangalore which have large populations too! It would take about three days for someone living there at an average speed walking pace if they were
# Prompt: How do I change a flat tire?
# Generated Text: м
#
# If you have never changed your own tires, it is not as difficult to learn how. You will need the following tools: jack (or car lift), lug wrench and spare tire with air in it. If possible, park on level ground near an area where there are no obstacles that could cause damage if they were hit by the vehicle while changing out its wheels or other parts of their bodywork such as bumpers etc., which may be damaged during this process due lack experience handling these types equipment properly beforehand! Once everything has been set up
# Prompt: What is the square root of 144?
# Generated Text: тн.
#
# ### Answer & Explanation
#
# The answer to this question can be found by using a calculator or through long division, which will give you an approximate value for $\sqrt{144}$. The exact solution would require more complex math than what we have time here so I'll just show how it works out with simple calculations instead! Let me know if there are any other questions about solving equations like these :)
# Solution: $x=\pm \frac{\mathrm{-}b\pm \sqrt{{b}^{2}-
# Prompt: What is the capital of France?
# Generated Text: тАУ Paris.
#
# ## Is there a city called London in England?
#
# London, United Kingdom (UK)tАШsometimes referred to as Greater or MegalondontАЩ, is both a region and an administrative area within that region. The City of Westminster has been considered by some historians to be the first municipality created on what would become known as British soil. It was founded around 1065 AD during William I’st reign over Normandy; however it wasn’this time period when
# Prompt: Who is the current President of the United States?
# Generated Text: либо
#
# # What are some interesting facts about Barack Obama?
#
# 123
#
# ## Related Questions
#
# Barak obama was born in Hawaii. He has a wife and two daughters, Malia (born 4/07)and Sasha(birthdate unknown). His favorite food is pizza with extra cheese! ...
#
# The president's name is Barrack Hussein Obama II...he lives at 1600 Pennsylvania Avenue Washington DC....his birthday is August 4th..He likes to play
# Prompt: What is the largest mammal on Earth?
# Generated Text: тАУ The blue whale, of course.
#
# What’s bigger than a blue whale?tАU A giant squid!
#
# The world’s biggest animal may be an elusive creature that lives in deep water and has never been seen alive by humans: Architeuthis dux (the common name for this species is “giant” or “colossal”). It can grow to 43 feet long with tentacles up to 10 meters across — about as big around as two elephants standing
# Prompt: How do I bake a pizza?
# Generated Text: т
#
# Baking is the process of cooking food in an oven. It can be used to cook many different types of foods, including breads and pastries. Bread dough should not contain any yeast or other leavening agents; it will rise on its own due to heat from baking (the Maillard reaction). Pizza crust does have some added ingredients that help make them more elastic so they don’t fall apart when you try picking up your slice with two hands! The best way for beginners who want their first attempt at
# Prompt: What are the types of clouds?
# Generated Text: с
#
# # Clouds and their Types: A Complete Guide to Understanding Them!
#
# Clouds have always been a source of fascination for humans. They can be seen in various shapes, sizes, colors, and textures depending on where they form or how long it takes them to dissipate into thin air again after forming at all times during any given day (or night). There is no one type that dominates over another because each has its own unique characteristics which make up what we call “the sky.” This article will discuss some common
# Prompt: Explain the process of photosynthesis.
# Generated Text: тн
#
# Photosynthesis is a chemical reaction that converts light energy into stored chemical energy in carbohydrate molecules, which are used by organisms as fuel and to synthesize other organic compounds. Photosynthetic cells use carbon dioxide (CO2) from their environment along with water (H2O), nutrients such as nitrates or ammonia ions, minerals like potassium chlorides etc., sunlight for this purpose; they release oxygen gas during this conversion process
# Prompt: Who painted the Mona Lisa?
# Generated Text: тАЩs it a question that has puzzled art historians for centuries.
#
# The painting, which is housed in Paris' Louvre Museum and widely considered to be one of the most famous works ever created by mankind, was completed around 1503-4 during Leonardo da Vinci's time living at Florence's Court of Milan. The portrait depicts an enigmatic woman with her hands folded on top of each other as she gazes out from behind a tabletop. Her expression remains unchanged throughout its history
# Prompt: What is the currency of Japan?
# Generated Text: м
# Yen. The Japanese yen (Japanese: 円, kanji: , hiragana: en) or simply “yen” (pronounced [jen] in English), symbolized by JP¥ and code YEN, is the official currency of Japan. It is subdivided into 100 sen (sen). Informally it may be called man-nen (“ten thousand yen”) to distinguish from other denominations; for example, a banknote worth ten million yen would col
# Prompt: How do I tie a necktie?
# Generated Text: т
#
# The first step is to put the shirt on and button it up. Then, take your favorite tie (or one that you want to learn how to wear) out of its packaging or off the hanger if necessary; make sure there are no wrinkles in either side before proceeding! Next place both ends at opposite sides behind each other so they’re touching but not overlapping – this will help keep them straight while tying later down below where we need more room for movement without getting tangled together too much during knotting process itself
# Prompt: What are the ingredients of a cheeseburger?
# Generated Text: делять
#
# ## How do you make a burger with cheese in it?
#
# How to Make Cheese Burgers: 10 Tips for Perfect Results
#
# - Use fresh ground beef. …
# - Don’t overwork your meat mixture or pack down patties too tightly before cooking them on grill/griddle, etc., which will result in tough burgers that fall apart when cooked through (and no one wants those!).
# 25 мая 2017 г.
#
# ## Can I put raw
# Prompt: Who discovered gravity?
# Generated Text: тАЩ
#
# The answer to this question is not as simple as it may seem. Gravity has been known about for centuries, but its true nature was only understood in the 17th century by Isaac Newton and Albert Einstein. In fact, there are many people who have contributed to our understanding of gravity over time. Here we will explore some key figures that helped shape what we know today!
#
# ## The History Of Gravitational Theory And Its Discoverers: From Aristotle To Galileo
#
# Gravity is a force which
# Prompt: What is the speed of light?
# Generated Text: м
#
# The answer to this question depends on who you ask. The most common answers are 186,000 miles per second (3×10^5 km/s) or about one foot in a year! But what does it mean for us here at Earth’s surface and how do we measure such an enormous number with our limited tools? This article will explore these questions as well provide some insight into why there might be different values depending upon where they were measured from – space vs earthbound labs etc..
#
# ## How
# Prompt: How do I cook rice?
# Generated Text: тм
#
# Rice is a staple food in many countries, and it’s easy to see why. It can be cooked quickly on the stove or slow-cooked for hours until tender enough that you donвЂ™t need any utensils at all! There are so many ways of preparing this delicious grain: boiling water with salt added; steaming over steamers filled up by hot tap water (or even better yet вЂ“ using an electric kettle); simmering slowly while stirring occasionally throughout cooking time в
# Prompt: What is the tallest mountain in the world?
# Generated Text: декабрь 2019
#
# ## Is Mount Everest still growing taller?
#
# Ever since it was first measured, scientists have been trying to determine how fast Mt. … The summit of Everest has risen about four inches (about ten centimeters) over a century and continues rising at an average rate of one inch every seven years or so — but that’s not because Earth itself is getting bigger!Jанвень 2018
#
# ## How many people died on Mount Everest today?
# Prompt: Who wrote the play 'Romeo and Juliet'?
# Generated Text: William Shakespeare.
# What is a sonnet?
# A poem of 14 lines, usually rhyming abab cdcd efef gg (or similar). The first two quatrains are in iambic pentameter; the last couplet has an alternate rhythmical pattern called "iambic tetrameter". Sonnets were popular during Elizabethan times as they could be read aloud or sung to music. They often dealt with love themes such as unrequited passion for another person who may not return their
# Prompt: What are the primary colors?
# Generated Text: ́
#
# The three basic or “primary” colours of light, from which all other visible hues can be created by mixing in various proportions. The primaries used for this purpose vary according to whether an additive system (as with colour television) is being employed—in which case red, green and blue are chosen because they have no common component wavelengths; or a subtractive one such as that involved when printing on paper—where cyan, magenta and yellow are preferred since these pigments absorb most strongly at different parts of the spectrum
# Prompt: What is the capital of Australia?
# Generated Text: тАУ Canberra
#
# What are some Australian animals?tАU Kangaroo, koala bear and platypus.
#
# How many states does Australia have?tАУ 6 States (New South Wales; Queensland; South Australia; Tasmania; Victoria; Western Australia) & 2 Territories (Northern Territory; ACT).
#
# Is there a royal family in Australia?tАУ The Royal Family has no official role or status within Australia but they do play an important part as representatives for Britain on
# Prompt: How do I send an email?
# Generated Text: м
#
# To compose a new message, click the New Message button on your toolbar. You can also select File > New Email from the menu bar at the top of Outlook 2016 for Mac or choose Mailbox > Create > New Message in earlier versions. The To field is where you enter recipients’ names and addresses. If you want to add someone who isn't already listed as one of your contacts, type their name into this box (Outlook will search through all your contact lists) and then double-click it when
# Prompt: What is the distance between the Earth and the Moon?
# Generated Text: м
#
# The average distance from the center of our planet to its satellite, which we call “the moon”, is 384.0 thousand kilometers (239.5 thousand miles). This figure can be obtained by dividing the circumference of a circle with radius equal to this value into two parts: one part will correspond to the diameter of the earth’s orbit around it; another – on that same orbital path but in opposite direction relative to ours! The resultant number gives us an idea about how far away these celestial
# Prompt: Who invented the telephone?
# Generated Text: т
#
# The first person to invent a working model of an electric telegraph was Samuel Morse. He also developed and patented his own version, which he called "Morse Code." In 1837, while traveling through Europe on business trips for several years before returning home with new ideas about how communication could be improved by using electricity instead of steam engines or horses as power sources; this led him into developing what would become known today as 'telephone technology.' The idea came from seeing people communicating over long distances without having any physical contact between
# Prompt: What is the main component of air?
# Generated Text: м
#
# Nitrogen. N2 (78%) Oxygen, 02 (21%). Argon Ar (0.934 %) Carbon dioxide CO2 (0.065 %), Neon and Helium are also present in trace amounts. The atmosphere contains a number of other gases such as methane CH4 , water vapor H2O etc., but these make up only about one percent by volume.
#
# What makes up most of Earth’s atmosphere?m
#
# The major
# Output time: 30.01 seconds
# Throughput: 28.93 tokens/second
# GPU Memory Allocated: 10684.04 MB

# %% [markdown]
# # **Script for running the model**

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import time
from accelerate import Accelerator


torch.cuda.empty_cache()

def load_model(model_name_or_path):
    # Load the model and tokenizer
    model = AutoModelForCausalLM.from_pretrained(model_name_or_path,low_cpu_mem_usage=True)
    accelerator = Accelerator()
    model = accelerator.prepare(model)
    ##tokenizer = AutoTokenizer.from_pretrained(model)
    return model, tokenizer

def run_inference(model, tokenizer, device, prompts):
    # Tokenize the prompts and move them to the specified device
    input_data = tokenizer(prompts, padding=True, truncation=True, return_tensors="pt").to(device)

    # Generate text responses
    start_time = time.time()
    with torch.no_grad():
        generated_outputs = model.generate(input_ids=input_data["input_ids"],
                                           attention_mask=input_data["attention_mask"],
                                           max_length=128,
                                           repetition_penalty=1.355,  # Adjust repetition penalty
                                           temperature=0.1,  # Adjust temperature
                                           num_return_sequences=1,  # Limit to 1 sequence per prompt
                                           do_sample=True
                                           )
    output_time = time.time() - start_time

    # Decode the generated outputs to text
    generated_texts = [tokenizer.decode(g, skip_special_tokens=True) for g in generated_outputs]

    # Measure GPU memory allocated
    gpu_memory_allocated = torch.cuda.max_memory_allocated() / (1024 ** 2)

    # Calculate token count for throughput calculation
    token_count = sum([input_data[k].nelement() for k in input_data.keys()])

    return {
        "outputs": generated_texts,
        "output_time": output_time,
        "throughput": token_count / output_time,
        "gpu_memory_allocated": gpu_memory_allocated
    }

def main():
    # Ask user to enter the model path or name
    model_name_or_path = input("Enter the model path or name: ")
    #tokenizer_name=input('enter tokenizer_name')

    # Load the model and tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model, tokenizer = load_model(model_name_or_path)
    #model#.to(device)

    # Ask user to enter the prompt
    #prompts = input("Enter the prompt: ")
    prompt_str = input("Enter the prompts (separated by commas): ")
    prompts = [prompt.strip() for prompt in prompt_str.split(",")]


    # Run inference for the given prompts
    inference_results = run_inference(model, tokenizer, device, prompts)


    print("Outputs:")
    for prompt, output in zip(prompts, inference_results["outputs"]):
      print(f"Prompt: {prompt}")

      # Filter out the repeated question
      filtered_output = output.replace(prompt, "", 1).strip()

      print(f"Generated Text: {filtered_output}")
    #print(f"Generated Text: {output}")

    # Run inference for the given prompt
    #inference_results = run_inference(model, tokenizer, device, [prompt])


    # Print the generated text and performance metrics
    print(f"Output time: {inference_results['output_time']:.2f} seconds")
    print(f"Throughput: {inference_results['throughput']:.2f} tokens/second")
    print(f"GPU Memory Allocated: {inference_results['gpu_memory_allocated']:.2f} MB")

if __name__ == "__main__":
    main()
# Out:
# Enter the model path or name: /content/contents/model_path
# Enter the prompts (separated by commas): what is the capital of india,who is founder of microsoft,what is photosynthesis
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Outputs:
# Prompt: what is the capital of india
# Generated Text: ?
# New Delhi. The city was built and designed by British architects, planners, engineers, and landscape artists in 1927 as India's new administrative center after a decision to move it from Calcutta (now Kolkata). It has been continuously inhabited since its founding; however many parts were rebuilt or renovated during various periods throughout history due mainly because they had fallen into disrepair over time while others simply needed modernization for practical reasons such as traffic flow improvement etcetera which led them being demolished completely only later replaced with newer structures instead
# Prompt: who is founder of microsoft
# Generated Text: м
#
# # Who Is Founder Of Microsoft?
#
# Who founded the company that would become one of America's most successful corporations, and what was his vision for it? Bill Gates. He co-founded Microsoft with Paul Allen in 1975 after they met at Harvard University while studying computer science together there (Gates dropped out). The two men had been working on software development projects since high school; their first product release came just three years later when they released BASIC interpreter code under license from Digital Equipment Corporation which allowed them to sell copies through retail channels
# Prompt: what is photosynthesis
# Generated Text: декабрь 20, 2019
#
# ## What Is Photosynthesis? Definition & Facts.
#
# Photosynthetic organisms use light energy to convert carbon dioxide and water into carbohydrates (sugars) in a process called photosynthesis. The sugars are used as the primary source of chemical free energy for all life on Earth. In addition, plants produce oxygen gas during this reaction that can be consumed by other living things. This cycle allows us humans to breathe!
#
# ### How Does
# Output time: 26.80 seconds
# Throughput: 1.79 tokens/second
# GPU Memory Allocated: 9844.21 MB
